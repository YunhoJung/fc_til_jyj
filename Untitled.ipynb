# %%
def bubble_sort(li):
    len_li = len(li)-1
    for i in range(len_li):
        print("{}번째".format(i))
        for j in range(len_li-i):
            print("    {}".format(j))
            if li[j] > li[j+1]:
                li[j], [j+1] = x[j+1], x[j]
                print("        {}와 {}를 바꿉니다.".format(x[j], x[j+1]))
                print("        결과:", x)
    return x

bubbleSort([9, 4, 1, 0, 7, 6, 2, 5, 3, 8])
# Out:
# 0번째
#     0
#         4와 9를 바꿉니다.
#         결과: [4, 9, 1, 0, 7, 6, 2, 5, 3, 8]
#     1
#         1와 9를 바꿉니다.
#         결과: [4, 1, 9, 0, 7, 6, 2, 5, 3, 8]
#     2
#         0와 9를 바꿉니다.
#         결과: [4, 1, 0, 9, 7, 6, 2, 5, 3, 8]
#     3
#         7와 9를 바꿉니다.
#         결과: [4, 1, 0, 7, 9, 6, 2, 5, 3, 8]
#     4
#         6와 9를 바꿉니다.
#         결과: [4, 1, 0, 7, 6, 9, 2, 5, 3, 8]
#     5
#         2와 9를 바꿉니다.
#         결과: [4, 1, 0, 7, 6, 2, 9, 5, 3, 8]
#     6
#         5와 9를 바꿉니다.
#         결과: [4, 1, 0, 7, 6, 2, 5, 9, 3, 8]
#     7
#         3와 9를 바꿉니다.
#         결과: [4, 1, 0, 7, 6, 2, 5, 3, 9, 8]
#     8
#         8와 9를 바꿉니다.
#         결과: [4, 1, 0, 7, 6, 2, 5, 3, 8, 9]
# 1번째
#     0
#         1와 4를 바꿉니다.
#         결과: [1, 4, 0, 7, 6, 2, 5, 3, 8, 9]
#     1
#         0와 4를 바꿉니다.
#         결과: [1, 0, 4, 7, 6, 2, 5, 3, 8, 9]
#     2
#     3
#         6와 7를 바꿉니다.
#         결과: [1, 0, 4, 6, 7, 2, 5, 3, 8, 9]
#     4
#         2와 7를 바꿉니다.
#         결과: [1, 0, 4, 6, 2, 7, 5, 3, 8, 9]
# ...
